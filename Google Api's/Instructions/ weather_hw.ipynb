# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\wabug\appdata\local\programs\python\python37-32\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\wabug\appdata\local\programs\python\python37-32\lib\site-packages (from citipy) (0.16)

# %%
 #Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 621

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
    time.sleep(6)
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=deputatskiy
# Processing Record 2 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=haines junction
# Processing Record 3 | Andros Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=andros town
# Processing Record 4 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chokurdakh
# Processing Record 5 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=new norfolk
# Processing Record 6 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nantucket
# Processing Record 7 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=albany
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=klaksvik
# Processing Record 9 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ushuaia
# Processing Record 10 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=belyy yar
# Processing Record 11 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tuatapere
# Processing Record 12 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=avarua
# Processing Record 13 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hambantota
# Processing Record 14 | Klerksdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=klerksdorp
# Processing Record 15 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dikson
# Processing Record 16 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kapaa
# Processing Record 17 | Puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=puri
# Processing Record 18 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=coahuayana
# Processing Record 19 | Makhinjauri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=makhinjauri
# Processing Record 20 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cape town
# Processing Record 21 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=airai
# Processing Record 22 | Reyes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=reyes
# Processing Record 23 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=riyadh
# Processing Record 24 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=faanui
# Processing Record 25 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=punta arenas
# Processing Record 26 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=atuona
# Processing Record 27 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=evensk
# Processing Record 28 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luanda
# Processing Record 29 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vila franca do campo
# Processing Record 30 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=richards bay
# Processing Record 31 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cherskiy
# Processing Record 32 | Kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kayes
# Processing Record 33 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=brae
# Processing Record 34 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=palmer
# Processing Record 35 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=san patricio
# Processing Record 36 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lompoc
# Processing Record 37 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kaitangata
# Processing Record 38 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=yellowknife
# Processing Record 39 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kavieng
# Processing Record 40 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bambous virieux
# City not found. Skipping...
# Processing Record 41 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=rawson
# Processing Record 42 | Guadalupe y Calvo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=guadalupe y calvo
# Processing Record 43 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=butaritari
# Processing Record 44 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=egvekinot
# Processing Record 45 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=codrington
# Processing Record 46 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=severo-kurilsk
# Processing Record 47 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=rikitea
# Processing Record 48 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=fortuna
# Processing Record 49 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hermanus
# Processing Record 50 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=puerto ayora
# Processing Record 51 | Marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=marienburg
# Processing Record 52 | Tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tanout
# Processing Record 53 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bethel
# Processing Record 54 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=upernavik
# Processing Record 55 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=jamestown
# Processing Record 56 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=carnarvon
# Processing Record 57 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=aklavik
# Processing Record 58 | Mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mercedes
# City not found. Skipping...
# Processing Record 59 | Sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sampit
# Processing Record 60 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mataura
# Processing Record 61 | Bouloupari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bouloupari
# Processing Record 62 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=barrow
# Processing Record 63 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mar del plata
# Processing Record 64 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=qaanaaq
# Processing Record 65 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vaini
# Processing Record 66 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hilo
# Processing Record 67 | Novorzhev
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=novorzhev
# Processing Record 68 | Nicoya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nicoya
# Processing Record 69 | Hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hohhot
# Processing Record 70 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=khatanga
# City not found. Skipping...
# Processing Record 71 | Amga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=amga
# Processing Record 72 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=srednekolymsk
# Processing Record 73 | Bogalusa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bogalusa
# Processing Record 74 | Wawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=wawa
# Processing Record 75 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nanortalik
# Processing Record 76 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=buraydah
# Processing Record 77 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mahebourg
# Processing Record 78 | Tala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tala
# Processing Record 79 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=saint george
# Processing Record 80 | Mikuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mikuni
# Processing Record 81 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nikolskoye
# City not found. Skipping...
# Processing Record 82 | Chuguyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chuguyevka
# Processing Record 83 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bandarbeyla
# Processing Record 84 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=constitucion
# Processing Record 85 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=takoradi
# Processing Record 86 | Catanzaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=catanzaro
# City not found. Skipping...
# Processing Record 87 | Lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lodja
# Processing Record 88 | Dalby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dalby
# Processing Record 89 | Bere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bere
# Processing Record 90 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port alfred
# City not found. Skipping...
# Processing Record 91 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=saint-philippe
# Processing Record 92 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kodiak
# Processing Record 93 | Lysyye Gory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lysyye gory
# Processing Record 94 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vestmanna
# Processing Record 95 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kenai
# Processing Record 96 | Puerto Narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=puerto narino
# Processing Record 97 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=longyearbyen
# City not found. Skipping...
# Processing Record 98 | Panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=panaba
# Processing Record 99 | Mondlo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mondlo
# Processing Record 100 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=arlit
# Processing Record 101 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=karratha
# Processing Record 102 | Coffs Harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=coffs harbour
# Processing Record 103 | Hervey Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hervey bay
# Processing Record 104 | Bourail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bourail
# Processing Record 105 | Bouna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bouna
# Processing Record 106 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=halifax
# Processing Record 107 | Sooke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sooke
# Processing Record 108 | Kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kapit
# Processing Record 109 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=jumla
# Processing Record 110 | Velen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=velen
# Processing Record 111 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=san policarpo
# Processing Record 112 | Nkhata Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nkhata bay
# Processing Record 113 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=isangel
# Processing Record 114 | Bayevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bayevo
# City not found. Skipping...
# Processing Record 115 | Berezniki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=berezniki
# Processing Record 116 | Wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=wasilla
# Processing Record 117 | Asekeyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=asekeyevo
# Processing Record 118 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=fairbanks
# Processing Record 119 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tasiilaq
# Processing Record 120 | Santander Jimenez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=santander jimenez
# Processing Record 121 | Tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tabuk
# Processing Record 122 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cabedelo
# Processing Record 123 | Plyussa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=plyussa
# Processing Record 124 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port lincoln
# Processing Record 125 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=yulara
# Processing Record 126 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=okhotsk
# Processing Record 127 | Dong Hoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dong hoi
# Processing Record 128 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kiama
# Processing Record 129 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bluff
# Processing Record 130 | Kondopoga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kondopoga
# Processing Record 131 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=castro
# Processing Record 132 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sept-iles
# Processing Record 133 | Guanambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=guanambi
# Processing Record 134 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ponta delgada
# Processing Record 135 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=thompson
# Processing Record 136 | Dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dali
# Processing Record 137 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luganville
# Processing Record 138 | Celina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=celina
# Processing Record 139 | Marigot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=marigot
# Processing Record 140 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=fukue
# Processing Record 141 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hithadhoo
# Processing Record 142 | Port Arthur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port arthur
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 143 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=padang
# Processing Record 144 | Masty
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=masty
# Processing Record 145 | Linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=linxia
# Processing Record 146 | Sinnai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sinnai
# Processing Record 147 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=portland
# Processing Record 148 | Chilca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chilca
# Processing Record 149 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bredasdorp
# Processing Record 150 | Tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tazovskiy
# Processing Record 151 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ilulissat
# Processing Record 152 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=esperance
# Processing Record 153 | Aden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=aden
# Processing Record 154 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=busselton
# Processing Record 155 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kavaratti
# City not found. Skipping...
# Processing Record 156 | Atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=atasu
# City not found. Skipping...
# Processing Record 157 | Iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=iranshahr
# Processing Record 158 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lethem
# Processing Record 159 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kruisfontein
# Processing Record 160 | Burley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=burley
# Processing Record 161 | Bucerias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bucerias
# City not found. Skipping...
# Processing Record 162 | Kharan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kharan
# Processing Record 163 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=provideniya
# Processing Record 164 | Qandala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=qandala
# Processing Record 165 | Morro Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=morro bay
# Processing Record 166 | Kainantu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kainantu
# City not found. Skipping...
# Processing Record 167 | West Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=west bay
# Processing Record 168 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=zhangye
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 169 | Paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=paamiut
# Processing Record 170 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bathsheba
# Processing Record 171 | Snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=snezhnogorsk
# Processing Record 172 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=victoria
# Processing Record 173 | Ghorawal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ghorawal
# Processing Record 174 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=agadez
# Processing Record 175 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hobart
# Processing Record 176 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pisco
# Processing Record 177 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=banda aceh
# Processing Record 178 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=raudeberg
# Processing Record 179 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=saskylakh
# Processing Record 180 | Chato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chato
# City not found. Skipping...
# Processing Record 181 | Colesberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=colesberg
# Processing Record 182 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port elizabeth
# Processing Record 183 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=georgetown
# Processing Record 184 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=zhigansk
# Processing Record 185 | Shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=shelburne
# Processing Record 186 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=grindavik
# Processing Record 187 | Nogliki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nogliki
# Processing Record 188 | Tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tevaitoa
# City not found. Skipping...
# Processing Record 189 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=east london
# Processing Record 190 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=belaya gora
# Processing Record 191 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=shingu
# Processing Record 192 | Aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=aswan
# Processing Record 193 | Uribia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=uribia
# Processing Record 194 | Khorramshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=khorramshahr
# Processing Record 195 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ust-kuyga
# Processing Record 196 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ponta do sol
# Processing Record 197 | Oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=oktyabrskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 198 | Kwinana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kwinana
# Processing Record 199 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ostrovnoy
# Processing Record 200 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tuktoyaktuk
# Processing Record 201 | Pokrovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pokrovsk
# Processing Record 202 | Salekhard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=salekhard
# Processing Record 203 | Tairua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tairua
# Processing Record 204 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dwarka
# Processing Record 205 | Altagracia de Orituco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=altagracia de orituco
# Processing Record 206 | Betsiamites
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=betsiamites
# Processing Record 207 | Denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=denpasar
# Processing Record 208 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mayor pablo lagerenza
# City not found. Skipping...
# Processing Record 209 | Pontal do Parana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pontal do parana
# Processing Record 210 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chuy
# Processing Record 211 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cidreira
# Processing Record 212 | Manikpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=manikpur
# Processing Record 213 | Morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=morehead
# Processing Record 214 | Yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=yinchuan
# Processing Record 215 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=laguna
# Processing Record 216 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=banjar
# Processing Record 217 | Xichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=xichang
# Processing Record 218 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=coolum beach
# Processing Record 219 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=geraldton
# Processing Record 220 | Phonhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=phonhong
# Processing Record 221 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pacific grove
# Processing Record 222 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lebu
# Processing Record 223 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=along
# Processing Record 224 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pevek
# Processing Record 225 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ballina
# Processing Record 226 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vostok
# Processing Record 227 | Khilok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=khilok
# Processing Record 228 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=salalah
# City not found. Skipping...
# Processing Record 229 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ixtapa
# Processing Record 230 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=broome
# Processing Record 231 | Itacoatiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=itacoatiara
# City not found. Skipping...
# Processing Record 232 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kununurra
# City not found. Skipping...
# Processing Record 233 | Merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=merrill
# Processing Record 234 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cap malheureux
# City not found. Skipping...
# Processing Record 235 | Krapivinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=krapivinskiy
# Processing Record 236 | Biu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=biu
# Processing Record 237 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=te anau
# Processing Record 238 | Kattivakkam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kattivakkam
# Processing Record 239 | Balestrand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=balestrand
# Processing Record 240 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tiznit
# Processing Record 241 | Tynset
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tynset
# Processing Record 242 | Umba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=umba
# City not found. Skipping...
# Processing Record 243 | Kirkwall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kirkwall
# Processing Record 244 | Katangli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=katangli
# Processing Record 245 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tautira
# Processing Record 246 | Fagernes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=fagernes
# Processing Record 247 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=meulaboh
# Processing Record 248 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vardo
# Processing Record 249 | Huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=huilong
# City not found. Skipping...
# Processing Record 250 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sao filipe
# Processing Record 251 | Paranapanema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=paranapanema
# City not found. Skipping...
# Processing Record 252 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=roma
# Processing Record 253 | Cobija
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cobija
# Processing Record 254 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=iqaluit
# Processing Record 255 | Douglas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=douglas
# Processing Record 256 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=arraial do cabo
# Processing Record 257 | Tengushevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tengushevo
# Processing Record 258 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=coquimbo
# Processing Record 259 | Durres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=durres
# Processing Record 260 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tura
# Processing Record 261 | Emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=emba
# Processing Record 262 | Tokat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tokat
# Processing Record 263 | Hearst
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hearst
# Processing Record 264 | Jalingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=jalingo
# Processing Record 265 | Nouakchott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nouakchott
# City not found. Skipping...
# Processing Record 266 | Tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tommot
# Processing Record 267 | Sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sawakin
# City not found. Skipping...
# Processing Record 268 | Copalillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=copalillo
# Processing Record 269 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=saint-francois
# Processing Record 270 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=namibe
# Processing Record 271 | Afsin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=afsin
# Processing Record 272 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lorengau
# Processing Record 273 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sitka
# Processing Record 274 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bowen
# Processing Record 275 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chernyshevskiy
# Processing Record 276 | Kaduy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kaduy
# Processing Record 277 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=camacha
# Processing Record 278 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=matara
# Processing Record 279 | Namie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=namie
# City not found. Skipping...
# Processing Record 280 | Mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mabaruma
# Processing Record 281 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=honiara
# Processing Record 282 | Nipawin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nipawin
# Processing Record 283 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=baykit
# Processing Record 284 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=antalaha
# Processing Record 285 | Luang Prabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luang prabang
# Processing Record 286 | Sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sompeta
# Processing Record 287 | Mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mnogovershinnyy
# Processing Record 288 | Shashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=shashi
# Processing Record 289 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=makakilo city
# Processing Record 290 | Cam Ranh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cam ranh
# Processing Record 291 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=marzuq
# Processing Record 292 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=aykhal
# Processing Record 293 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ahipara
# Processing Record 294 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pangnirtung
# Processing Record 295 | Lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=lahaina
# Processing Record 296 | Tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tshikapa
# Processing Record 297 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=shenjiamen
# Processing Record 298 | Hope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hope
# Processing Record 299 | Nova Russas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nova russas
# Processing Record 300 | Bhikangaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bhikangaon
# Processing Record 301 | Tsaratanana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tsaratanana
# Processing Record 302 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vila velha
# Processing Record 303 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=leningradskiy
# Processing Record 304 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kaeo
# Processing Record 305 | Kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kushima
# Processing Record 306 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=davila
# Processing Record 307 | Khairagarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=khairagarh
# Processing Record 308 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sinnamary
# Processing Record 309 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=maniitsoq
# Processing Record 310 | Poltava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=poltava
# Processing Record 311 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=shimoda
# Processing Record 312 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dingle
# Processing Record 313 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=manggar
# Processing Record 314 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mayo
# Processing Record 315 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=homer
# Processing Record 316 | Odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=odienne
# Processing Record 317 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=harper
# City not found. Skipping...
# Processing Record 318 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=colares
# Processing Record 319 | Yagodnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=yagodnoye
# Processing Record 320 | Cacu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cacu
# Processing Record 321 | San Ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=san ramon
# Processing Record 322 | Luan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luan
# Processing Record 323 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=carutapera
# Processing Record 324 | High Level
# ...
# Processing Record 448 | Fuyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=fuyang
# Processing Record 449 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mount gambier
# Processing Record 450 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=general roca
# Processing Record 451 | Buctzotz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=buctzotz
# Processing Record 452 | Masuguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=masuguru
# City not found. Skipping...
# Processing Record 453 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port-cartier
# Processing Record 454 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=dunedin
# Processing Record 455 | Santa Marinella
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=santa marinella
# Processing Record 456 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ciudad bolivar
# Processing Record 457 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kiunga
# Processing Record 458 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=saint-joseph
# Processing Record 459 | Mahdalynivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mahdalynivka
# Processing Record 460 | Krylovskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=krylovskaya
# Processing Record 461 | Gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=gornopravdinsk
# Processing Record 462 | Tres Arroyos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tres arroyos
# Processing Record 463 | Abonnema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=abonnema
# Processing Record 464 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=christchurch
# Processing Record 465 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=manta
# Processing Record 466 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=torbay
# Processing Record 467 | Port Said
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=port said
# Processing Record 468 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=xining
# Processing Record 469 | Gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=gazanjyk
# Processing Record 470 | Suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=suntar
# City not found. Skipping...
# Processing Record 471 | Beni Suef
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=beni suef
# Processing Record 472 | Paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=paka
# Processing Record 473 | Khadzhalmakhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=khadzhalmakhi
# Processing Record 474 | Balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=balkhash
# Processing Record 475 | Bom Jesus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bom jesus
# Processing Record 476 | Grugliasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=grugliasco
# Processing Record 477 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=half moon bay
# Processing Record 478 | Jagtial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=jagtial
# Processing Record 479 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=axim
# City not found. Skipping...
# Processing Record 480 | Mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mehran
# Processing Record 481 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=namatanai
# Processing Record 482 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=huarmey
# Processing Record 483 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ribeira grande
# City not found. Skipping...
# Processing Record 484 | Geilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=geilo
# City not found. Skipping...
# Processing Record 485 | Sukpak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sukpak
# Processing Record 486 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=bilma
# Processing Record 487 | Cine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=cine
# Processing Record 488 | Talaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=talaya
# City not found. Skipping...
# Processing Record 489 | Pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pathein
# Processing Record 490 | Buenos Aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=buenos aires
# Processing Record 491 | Pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=pimentel
# Processing Record 492 | Estremoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=estremoz
# Processing Record 493 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luderitz
# Processing Record 494 | Zaraza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=zaraza
# Processing Record 495 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=labuhan
# Processing Record 496 | La Romana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=la romana
# Processing Record 497 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=henties bay
# Processing Record 498 | Luebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=luebo
# Processing Record 499 | Tankhoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tankhoy
# Processing Record 500 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=juneau
# Processing Record 501 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hasaki
# Processing Record 502 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=berlevag
# Processing Record 503 | Turtas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=turtas
# Processing Record 504 | Caernarfon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=caernarfon
# Processing Record 505 | Kyshtovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kyshtovka
# Processing Record 506 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=coihaique
# Processing Record 507 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=trincomalee
# Processing Record 508 | Redlands
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=redlands
# Processing Record 509 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=caravelas
# Processing Record 510 | Antropovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=antropovo
# Processing Record 511 | Santa Isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=santa isabel
# Processing Record 512 | Zuwarah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=zuwarah
# Processing Record 513 | Longfeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=longfeng
# Processing Record 514 | Grass Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=grass valley
# Processing Record 515 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hualmay
# Processing Record 516 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=komsomolskiy
# Processing Record 517 | Santiago de Cao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=santiago de cao
# Processing Record 518 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sorland
# Processing Record 519 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=hofn
# Processing Record 520 | Kasongo-Lunda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kasongo-lunda
# Processing Record 521 | Berestechko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=berestechko
# Processing Record 522 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=itarema
# Processing Record 523 | Sicuani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=sicuani
# Processing Record 524 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=iracoubo
# Processing Record 525 | Yukamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=yukamenskoye
# Processing Record 526 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=los llanos de aridane
# Processing Record 527 | Kirkkonummi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kirkkonummi
# Processing Record 528 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=champerico
# Processing Record 529 | Road Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=road town
# Processing Record 530 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=acajutla
# City not found. Skipping...
# Processing Record 531 | Isiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=isiro
# Processing Record 532 | Vanimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=vanimo
# Processing Record 533 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=guerrero negro
# Processing Record 534 | Esso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=esso
# Processing Record 535 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=ruteng
# Processing Record 536 | Chartres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=chartres
# Processing Record 537 | Atyashevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=atyashevo
# Processing Record 538 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=mahajanga
# Processing Record 539 | Scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=scarborough
# Processing Record 540 | Kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=kerema
# Processing Record 541 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=salinopolis
# Processing Record 542 | Constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=constantine
# Processing Record 543 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=tual
# Processing Record 544 | Koshurnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=koshurnikovo
# City not found. Skipping...
# Processing Record 545 | Rodrigues Alves
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=rodrigues alves
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 546 | Esil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=esil
# Processing Record 547 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=nome
# Processing Record 548 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=labuan
# Processing Record 549 | Jorochito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=jorochito
# Processing Record 550 | San Pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=san pedro
# Processing Record 551 | Antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=antsohihy
# Processing Record 552 | Meridian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=meridian
# Processing Record 553 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=batticaloa
# Processing Record 554 | Elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=600da2e6978f3ff66d3ea63149a1114b&q=elko

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_df = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_df.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
# Save data frame to CSV
weather_df.to_csv('output_data_file',index=False)


# Display data frame head 
weather_df.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Deputatskiy         100      RU  1570043496        87  69.30  139.90
# 1  Haines Junction          67      CA  1570043610        75  60.75 -137.51
# 2      Andros Town          75      BS  1570043612        74  24.73  -77.79
# 3       Chokurdakh          99      RU  1570043534        92  70.62  147.90
# 4      New Norfolk          75      AU  1570043616        66 -42.78  147.06
#
#    Max Temp  Wind Speed
# 0     20.36       23.04
# 1     35.12        4.70
# 2     84.20       13.87
# 3     26.48       16.08
# 4     53.60       10.29

# %%
#plotting the data
#Latitude vs Temperature

plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", s=10)
plt.title("City Latitude vs. City Temperature")
plt.ylabel("City Temperature (F)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Temperature_v_Latitude.png")
plt.show()

# %%
#Latitude vs Humidity Plot

plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", s=10)
plt.title("City Latitude vs. City Humidity")
plt.ylabel("City Humidity (%)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Humidity_v_Latitude.png")
plt.show()

# %%
#Latitude vs cloudiness plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", s=10)
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("City Cloudiness (%)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("Cloudiness_v_Latitude.png")
plt.show()

# %%
#Latitude vs wind speed plot 
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", s=10)
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("City Wind Speed (mph)")
plt.xlabel("City Latitude")
plt.grid(True)

plt.savefig("WindSpeed_v_Latitude.png")
plt.show()
